# %%
#Object = properties + methond (資料 + 函式)
class Cat:pass

a_cat=Cat()
a_cat.age=3
a_cat.name = "Mr. Fuzzybuttons"
a_cat.nemesis = another_cat
a_cat.nemesis.name = 'Mr. Bigglesworth'
a_cat.nemesis.name
# Out:
# 'Mr. Bigglesworth'

# %%
# 函示下的物件
class Cat():
    def __init__(self,name):
        self.name=name
        
furball = Cat('Grumpy')

# %%
#繼承：從父類別繼承
class Car():
    pass

class Yugo(Car):
    pass
class Car():
    def exclaim(self):
        print("I'm a Car!")
class Yugo(Car):
    pass

give_me_a_car= Car()
give_me_a_yugo= Yugo()
give_me_a_car.exclaim()
give_me_a_yugo.exclaim()
# Out:
# I'm a Car!
# I'm a Car!

# %%
#覆寫法
class Car():
    def exclaim(self):
        print("I'm a Car!")
class Yugo(Car):
    def exclaim(self):
        print("I'm a Yugo! Much like a Car, but more Yugo-ish.")
give_me_a_car= Car()
give_me_a_Yugo=Yugo()

class Person():
    def __init__(self,name):
        self.name = name
class MDperson(Person):
    def __init__(self,name):
        self.name = "Doctor:"+name
doctor=MDperson('Fudd')
doctor.name
# Out:
# 'Doctor:Fudd'

# %%
#添加法
class Car():
    def exclaim(self):
        print("I'm a Car!")
class Yugo(Car):
    def exclaim(self):
        print("I'm a Yugo! Much like a Car, but more Yugo-ish")
    def need_a_push(self):
        print("A little help here?")
give_me_a_car=Car()
give_me_a_Yugo=Yugo()
give_me_a_Yugo.need_a_push()
# Out:
# A little help here?

# %%
#用super()來取得父類別的幫助
class Person():
    def __init__(self,name):
        self.name=name
class EmailPerson(Person):
    def __init__(self,name, email):
        super().__init__(name)
        self.email = email
Bob = EmailPerson('Bob Frapples','bob@frapples.com')
Bob.name
Bob.email

#這樣可以讓原先不足的函式有新的更改方向
# Out:
# 'bob@frapples.com'

# %%
#多重繼承
class Animal:
    def says(self):
        return 'I speak!'
class Horse(Animal):
    def says(self):
        return 'Neigh!'
class Donkeys(Animal):
    def says(self):
        return 'Hee-haw'
class Mule(Donkeys, Horse):
    pass
class Hinny(Horse, Donkeys):
    pass
Mule.mro()
# Out:
# [__main__.Mule, __main__.Donkeys, __main__.Horse, __main__.Animal, object]

# %%
#Python 沒有屬性隱私的問題，只能透過property來處理
class Duck():
    def _int_(self, input_name):
        self.hidden_name = input_name
    def get_name(self):
        print('inside the getter')
        return self.hidden_name
    def set_name(self, input_name):
        print('inside the setter')
        self.hidden_name = input_name
    name = property(get_name, set_name)
    don= Duck('Donald')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-16d8c492fafc> in <module>
#       1 #Python 沒有屬性隱私的問題，只能透過property來處理
# ----> 2 class Duck():
#       3     def _int_(self, input_name):
#       4         self.hidden_name = input_name
#       5     def get_name(self):
#
# <ipython-input-9-16d8c492fafc> in Duck()
#      10         self.hidden_name = input_name
#      11     name = property(get_name, set_name)
# ---> 12     don= Duck('Donald')
#
# TypeError: Duck() takes no arguments

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-89b45a2ae8b1> in <module>
# ----> 1 don= Duck('Donald')
#
# TypeError: Duck() takes no arguments
